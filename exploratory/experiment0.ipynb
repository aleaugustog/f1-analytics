# %% [markdown]
# # F1 Experiment 0

# %%
import pandas as pd

meetings_df = pd.read_json('https://api.openf1.org/v1/meetings?year=2025')
meetings_df
# Out:
#     meeting_key  circuit_key circuit_short_name meeting_code     location  \
# 0          1253           63             Sakhir          BRN       Sakhir
# 1          1254           10          Melbourne          AUS    Melbourne
# 2          1255           49           Shanghai          CHN     Shanghai
# 3          1256           46             Suzuka          JPN       Suzuka
# 4          1257           63             Sakhir          BRN       Sakhir
# 5          1258          149             Jeddah          KSA       Jeddah
# 6          1259          151              Miami          USA        Miami
# 7          1260            6              Imola          ITA        Imola
# 8          1261           22        Monte Carlo          MON       Monaco
# 9          1262           15          Catalunya          ESP    Barcelona
# 10         1263           23           Montreal          CAN     Montréal
# 11         1264           19          Spielberg          AUT    Spielberg
# 12         1277            2        Silverstone          GBR  Silverstone
#
#     country_key country_code    country_name               meeting_name  \
# 0            36          BRN         Bahrain         Pre-Season Testing
# 1             5          AUS       Australia      Australian Grand Prix
# 2            53          CHN           China         Chinese Grand Prix
# 3             4          JPN           Japan        Japanese Grand Prix
# 4            36          BRN         Bahrain         Bahrain Grand Prix
# 5           153          KSA    Saudi Arabia   Saudi Arabian Grand Prix
# 6            19          USA   United States           Miami Grand Prix
# 7            13          ITA           Italy  Emilia Romagna Grand Prix
# 8           114          MON          Monaco          Monaco Grand Prix
# 9             1          ESP           Spain         Spanish Grand Prix
# 10           46          CAN          Canada        Canadian Grand Prix
# 11           17          AUT         Austria        Austrian Grand Prix
# 12            2          GBR  United Kingdom         British Grand Prix
#
#                                 meeting_official_name gmt_offset  \
# 0            FORMULA 1 ARAMCO PRE-SEASON TESTING 2025   03:00:00
# 1   FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ...   11:00:00
# 2          FORMULA 1 HEINEKEN CHINESE GRAND PRIX 2025   08:00:00
# 3          FORMULA 1 LENOVO JAPANESE GRAND PRIX 2025    09:00:00
# 4          FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2025   03:00:00
# 5         FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2025   03:00:00
# 6          FORMULA 1 CRYPTO.COM MIAMI GRAND PRIX 2025  -04:00:00
# 7   FORMULA 1 AWS GRAN PREMIO DEL MADE IN ITALY E ...   02:00:00
# 8       FORMULA 1 TAG HEUER GRAND PRIX DE MONACO 2025   02:00:00
# 9         FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2025   02:00:00
# 10        FORMULA 1 PIRELLI GRAND PRIX DU CANADA 2025  -04:00:00
# 11     FORMULA 1 MSC CRUISES AUSTRIAN GRAND PRIX 2025   02:00:00
# 12    FORMULA 1 QATAR AIRWAYS BRITISH GRAND PRIX 2025   01:00:00
#
#                    date_start  year
# 0   2025-02-26T07:00:00+00:00  2025
# 1   2025-03-14T01:30:00+00:00  2025
# 2   2025-03-21T03:30:00+00:00  2025
# 3   2025-04-04T02:30:00+00:00  2025
# 4   2025-04-11T11:30:00+00:00  2025
# 5   2025-04-18T13:30:00+00:00  2025
# 6   2025-05-02T16:30:00+00:00  2025
# 7   2025-05-16T11:30:00+00:00  2025
# 8   2025-05-23T11:30:00+00:00  2025
# 9   2025-05-30T11:30:00+00:00  2025
# 10  2025-06-13T17:30:00+00:00  2025
# 11  2025-06-27T11:30:00+00:00  2025
# 12  2025-07-04T11:30:00+00:00  2025

# %% [markdown]
# ## Sessions

# %%
sessions_df = pd.read_json('https://api.openf1.org/v1/sessions?meeting_key=1277')
sessions_df
# Out:
#    meeting_key  session_key     location                 date_start  \
# 0         1277         9940  Silverstone  2025-07-04T11:30:00+00:00
# 1         1277         9941  Silverstone  2025-07-04T15:00:00+00:00
# 2         1277         9942  Silverstone  2025-07-05T10:30:00+00:00
# 3         1277         9943  Silverstone  2025-07-05T14:00:00+00:00
# 4         1277         9947  Silverstone  2025-07-06T14:00:00+00:00
#
#                     date_end session_type session_name  country_key  \
# 0  2025-07-04T12:30:00+00:00     Practice   Practice 1            2
# 1  2025-07-04T16:00:00+00:00     Practice   Practice 2            2
# 2  2025-07-05T11:30:00+00:00     Practice   Practice 3            2
# 3  2025-07-05T15:00:00+00:00   Qualifying   Qualifying            2
# 4  2025-07-06T16:00:00+00:00         Race         Race            2
#
#   country_code    country_name  circuit_key circuit_short_name gmt_offset  \
# 0          GBR  United Kingdom            2        Silverstone   01:00:00
# 1          GBR  United Kingdom            2        Silverstone   01:00:00
# 2          GBR  United Kingdom            2        Silverstone   01:00:00
# 3          GBR  United Kingdom            2        Silverstone   01:00:00
# 4          GBR  United Kingdom            2        Silverstone   01:00:00
#
#    year
# 0  2025
# 1  2025
# 2  2025
# 3  2025
# 4  2025

# %% [markdown]
# ## Stints

# %%
stints_df = pd.read_json('https://api.openf1.org/v1/stints?session_key=9940')

compound_to_color = {
    "SOFT": "#FF0000",   # red
    "MEDIUM": "#FFFF00", # yellow
    "HARD": "#FFFFFF",   # white
}

# Map compound colors to the stints DataFrame
stints_df["compound_color"] = stints_df["compound"].map(compound_to_color)

stints_df
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0          1277         9940             1             23          1        1
# 1          1277         9940             1             55          1        1
# 2          1277         9940             1             31          1        2
# 3          1277         9940             1             16          1        3
# 4          1277         9940             1             63          1        3
# ..          ...          ...           ...            ...        ...      ...
# 83         1277         9940             4             30         19       27
# 84         1277         9940             4              6         19       28
# 85         1277         9940             5             23         20       30
# 86         1277         9940             4             97         21       25
# 87         1277         9940             6             55         22       26
#
#    compound  tyre_age_at_start compound_color
# 0      HARD                  0        #FFFFFF
# 1      HARD                  0        #FFFFFF
# 2    MEDIUM                  0        #FFFF00
# 3    MEDIUM                  0        #FFFF00
# 4    MEDIUM                  0        #FFFF00
# ..      ...                ...            ...
# 83     SOFT                  5        #FF0000
# 84   MEDIUM                 11        #FFFF00
# 85     SOFT                  0        #FF0000
# 86     SOFT                  5        #FF0000
# 87     SOFT                  3        #FF0000
#
# [88 rows x 9 columns]

# %% [markdown]
# ### Single-driver Stints

# %%
driver_stints_df = stints_df[stints_df['driver_number'] == 4]
driver_stints_df
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 12         1277         9940             1              4          1        9
# 38         1277         9940             2              4         10       16
# 74         1277         9940             3              4         17       26
#
#    compound  tyre_age_at_start compound_color
# 12   MEDIUM                  0        #FFFF00
# 38     SOFT                  0        #FF0000
# 74   MEDIUM                  9        #FFFF00

# %% [markdown]
# ## Laps

# %%
laps_df = pd.read_json('https://api.openf1.org/v1/laps?session_key=9940&driver_number=4')
laps_df = laps_df[['session_key', 'driver_number', 'lap_number', 'is_pit_out_lap', 'lap_duration']]
laps_df
# Out:
#     session_key  driver_number  lap_number  is_pit_out_lap  lap_duration
# 0          9940              4           1            True           NaN
# 1          9940              4           2           False        88.645
# 2          9940              4           3           False       155.986
# 3          9940              4           4           False       106.784
# 4          9940              4           5           False        87.991
# 5          9940              4           6           False       153.728
# 6          9940              4           7           False       127.989
# 7          9940              4           8           False        88.105
# 8          9940              4           9           False       116.336
# 9          9940              4          10            True       720.657
# 10         9940              4          11           False        87.354
# 11         9940              4          12           False       143.132
# 12         9940              4          13           False       143.464
# 13         9940              4          14           False       119.143
# 14         9940              4          15           False        86.915
# 15         9940              4          16           False       113.920
# 16         9940              4          17            True       470.230
# 17         9940              4          18           False        92.647
# 18         9940              4          19           False        92.264
# 19         9940              4          20           False        92.406
# 20         9940              4          21           False        92.330
# 21         9940              4          22           False        92.086
# 22         9940              4          23           False        92.017
# 23         9940              4          24           False        91.989
# 24         9940              4          25           False       129.690
# 25         9940              4          26           False       149.316

# %% [markdown]
# ### Matching each lap to the corresponding stint

# %%
# Matching each lap to the corresponding stint on a new DF
laps_stints_df = laps_df.merge(stints_df, on=['session_key', 'driver_number'])
laps_stints_df = laps_stints_df[(laps_stints_df['lap_number'] >= laps_stints_df['lap_start']) & (laps_stints_df['lap_number'] <= laps_stints_df['lap_end']) & (laps_stints_df['is_pit_out_lap'] == False)]
laps_stints_df
# Out:
#     session_key  driver_number  lap_number  is_pit_out_lap  lap_duration  \
# 3          9940              4           2           False        88.645
# 6          9940              4           3           False       155.986
# 9          9940              4           4           False       106.784
# 12         9940              4           5           False        87.991
# 15         9940              4           6           False       153.728
# 18         9940              4           7           False       127.989
# 21         9940              4           8           False        88.105
# 24         9940              4           9           False       116.336
# 31         9940              4          11           False        87.354
# 34         9940              4          12           False       143.132
# 37         9940              4          13           False       143.464
# 40         9940              4          14           False       119.143
# 43         9940              4          15           False        86.915
# 46         9940              4          16           False       113.920
# 53         9940              4          18           False        92.647
# 56         9940              4          19           False        92.264
# 59         9940              4          20           False        92.406
# 62         9940              4          21           False        92.330
# 65         9940              4          22           False        92.086
# 68         9940              4          23           False        92.017
# 71         9940              4          24           False        91.989
# 74         9940              4          25           False       129.690
# 77         9940              4          26           False       149.316
#
#     meeting_key  stint_number  lap_start  lap_end compound  tyre_age_at_start  \
# 3          1277             1          1        9   MEDIUM                  0
# 6          1277             1          1        9   MEDIUM                  0
# 9          1277             1          1        9   MEDIUM                  0
# 12         1277             1          1        9   MEDIUM                  0
# 15         1277             1          1        9   MEDIUM                  0
# 18         1277             1          1        9   MEDIUM                  0
# 21         1277             1          1        9   MEDIUM                  0
# 24         1277             1          1        9   MEDIUM                  0
# 31         1277             2         10       16     SOFT                  0
# 34         1277             2         10       16     SOFT                  0
# 37         1277             2         10       16     SOFT                  0
# 40         1277             2         10       16     SOFT                  0
# 43         1277             2         10       16     SOFT                  0
# 46         1277             2         10       16     SOFT                  0
# 53         1277             3         17       26   MEDIUM                  9
# 56         1277             3         17       26   MEDIUM                  9
# 59         1277             3         17       26   MEDIUM                  9
# 62         1277             3         17       26   MEDIUM                  9
# 65         1277             3         17       26   MEDIUM                  9
# 68         1277             3         17       26   MEDIUM                  9
# 71         1277             3         17       26   MEDIUM                  9
# 74         1277             3         17       26   MEDIUM                  9
# 77         1277             3         17       26   MEDIUM                  9
#
#    compound_color
# 3         #FFFF00
# 6         #FFFF00
# 9         #FFFF00
# 12        #FFFF00
# 15        #FFFF00
# 18        #FFFF00
# 21        #FFFF00
# 24        #FFFF00
# 31        #FF0000
# 34        #FF0000
# 37        #FF0000
# 40        #FF0000
# 43        #FF0000
# 46        #FF0000
# 53        #FFFF00
# 56        #FFFF00
# 59        #FFFF00
# 62        #FFFF00
# 65        #FFFF00
# 68        #FFFF00
# 71        #FFFF00
# 74        #FFFF00
# 77        #FFFF00

# %%
notna_laps_df = laps_stints_df[laps_stints_df['lap_duration'].notna()]
notna_laps_df['lap_duration'].describe()
# Out:
# count     23.000000
# mean     110.619000
# std       24.600305
# min       86.915000
# 25%       92.003000
# 50%       92.647000
# 75%      128.839500
# max      155.986000
# Name: lap_duration, dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is called df and has columns:
# 'lap_number', 'lap_duration', 'compound_color'

plt.figure(figsize=(12, 6), facecolor='black')

ax = plt.gca()
ax.set_facecolor('black')

plt.bar(
    x=notna_laps_df["lap_number"],
    height=notna_laps_df["lap_duration"],
    color=notna_laps_df["compound_color"]
)

ax.tick_params(colors='white')  # Tick labels
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
plt.xlabel("Lap Number", color='white')
plt.ylabel("Lap Duration (s)", color='white')
plt.title("Lap Duration by Lap", color='white')
plt.grid(True, axis='y', linestyle='--', alpha=0.5, color='white')

plt.tight_layout()
plt.show()
